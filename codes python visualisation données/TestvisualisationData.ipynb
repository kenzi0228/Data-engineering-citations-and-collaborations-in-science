# %%
import pandas as pd

data = pd.read_json(r"C:\Users\Kenzi\Documents\MIASHS\L3 MIAGE\Nanterre\Semestre 6\GRAPHES ET OPEN DATA\projet\Dataset\Split_fusionné\Filtered_by_1_2020_merged.json")

# %%
datafiltered = data.loc[data["year"] == 2020]

# %%
data
# Out:
#         year                                              title  \
# 0       2020   Genetic Programming for Natural Language Parsing
# 1       2020  Social Structural Analysis of Street-Involved ...
# 2       2020  Study of task processes for improving programm...
# 3       2020  Simultaneous Localization and Mapping in a Hyb...
# 4       2020  A trichotomy for regular simple path queries o...
# ...      ...                                                ...
# 234479  2020  Validation of Student Psychological Player Typ...
# 234480  2020  Design and Implementation of an IoT Based Bagg...
# 234481  2020    An Efficient Holistic Schema Matching Approach.
# 234482  2020  A Statistical Linguistic Terms Interrelationsh...
# 234483  2020  Drug Verification System Using Quick Response ...
#
#                              _id  \
# 0       53e99953b7602d97021940cf
# 1       53e999b5b7602d97021fbb42
# 2       53e9a1e2b7602d9702ae2641
# 3       53e9a41cb7602d9702d36afc
# ...

# %%
datafiltered.to_json(r"C:\Users\Kenzi\Documents\MIASHS\L3 MIAGE\Nanterre\Semestre 6\GRAPHES ET OPEN DATA\projet\Dataset\Split_filtré\Split_9_Filtered_by_2020.json")
